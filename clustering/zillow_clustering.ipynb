# %%
from aquire_zillow import get_connection
from aquire_zillow import get_zillow_data

# %%
#test the functions and put zillow data into dataframe
zillow_df=get_zillow_data()

# %%
zillow_df.head()
# Out:
#    basementsqft  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 0           NaN          2.0         3.0                2.0
# 1           NaN          3.5         4.0                3.5
# 2           NaN          3.0         2.0                3.0
# 3           NaN          2.0         2.0                2.0
# 4           NaN          2.5         4.0                2.5
#
#    finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 0                       NaN                        1684.0
# 1                       NaN                        2263.0
# 2                       NaN                        2217.0
# 3                       NaN                         839.0
# 4                       NaN                        2283.0
#
#    finishedsquarefeet12  finishedsquarefeet13  finishedsquarefeet15  \
# 0                1684.0                   NaN                   NaN
# 1                2263.0                   NaN                   NaN
# ...
